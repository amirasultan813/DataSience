# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Desktop/data/Placement_Data_Full_Class.csv')
data
# Out:
#      serial_num gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0             1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1             2      M  79.33  Central  78.33   Others   Science     77.48
# 2             3      M  65.00  Central  68.00  Central      Arts     64.00
# 3             4      M  56.00  Central  52.00  Central   Science     52.00
# 4             5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..          ...    ...    ...      ...    ...      ...       ...       ...
# 210         211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211         212      M  58.00   Others  60.00   Others   Science     72.00
# 212         213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213         214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214         215      M  62.00  Central  58.00   Others   Science     53.00
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   serial_num      215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
data.shape
# Out:
# (215, 15)

# %%
data.sort_index(ascending=True)
# Out:
#      serial_num gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0             1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1             2      M  79.33  Central  78.33   Others   Science     77.48
# 2             3      M  65.00  Central  68.00  Central      Arts     64.00
# 3             4      M  56.00  Central  52.00  Central   Science     52.00
# 4             5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..          ...    ...    ...      ...    ...      ...       ...       ...
# 210         211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211         212      M  58.00   Others  60.00   Others   Science     72.00
# 212         213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213         214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214         215      M  62.00  Central  58.00   Others   Science     53.00
#
# ...

# %%
data.index.name='serial_num'

# %%
data
# Out:
#             serial_num gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# serial_num
# 0                    1      M  67.00   Others  91.00   Others  Commerce
# 1                    2      M  79.33  Central  78.33   Others   Science
# 2                    3      M  65.00  Central  68.00  Central      Arts
# 3                    4      M  56.00  Central  52.00  Central   Science
# 4                    5      M  85.80  Central  73.60  Central  Commerce
# ...                ...    ...    ...      ...    ...      ...       ...
# 210                211      M  80.60   Others  82.00   Others  Commerce
# 211                212      M  58.00   Others  60.00   Others   Science
# 212                213      M  67.00   Others  67.00   Others  Commerce
# 213                214      F  74.00   Others  66.00   Others  Commerce
# 214                215      M  62.00  Central  58.00   Others   Science
#
#             degree_p   degree_t workex  etest_p specialisation  mba_p  \
# serial_num
# ...

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ### Missing Values

# %%
data.isnull().sum()
# Out:
# serial_num         0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
data.interpolate(method='linear',inplace=True) # by default >> linear
# data.fillna(data.mean())

# %%
data
# Out:
#             serial_num gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# serial_num
# 0                    1      M  67.00   Others  91.00   Others  Commerce
# 1                    2      M  79.33  Central  78.33   Others   Science
# 2                    3      M  65.00  Central  68.00  Central      Arts
# 3                    4      M  56.00  Central  52.00  Central   Science
# 4                    5      M  85.80  Central  73.60  Central  Commerce
# ...                ...    ...    ...      ...    ...      ...       ...
# 210                211      M  80.60   Others  82.00   Others  Commerce
# 211                212      M  58.00   Others  60.00   Others   Science
# 212                213      M  67.00   Others  67.00   Others  Commerce
# 213                214      F  74.00   Others  66.00   Others  Commerce
# 214                215      M  62.00  Central  58.00   Others   Science
#
#             degree_p   degree_t workex  etest_p specialisation  mba_p  \
# serial_num
# ...

# %% [markdown]
# ### Check Unique Values

# %%
data['gender'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
data['ssc_b'].unique()
# Out:
# array(['Others', 'Central'], dtype=object)

# %%
data['degree_t'].unique()
# Out:
# array(['Sci&Tech', 'Comm&Mgmt', 'Others'], dtype=object)

# %%
data['specialisation'].unique()
# Out:
# array(['Mkt&HR', 'Mkt&Fin'], dtype=object)

# %%
data['workex'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data['status'].unique()
# Out:
# array(['Placed', 'Not Placed'], dtype=object)

# %% [markdown]
# ### Grouping Data

# %%
data.groupby(by='gender',axis=1)

# %%
data.groupby(by='gender').count()
# Out:
#         serial_num  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# gender
# F               76     76     76     76     76     76        76        76
# M              139    139    139    139    139    139       139       139
#
#         workex  etest_p  specialisation  mba_p  status  salary
# gender
# F           76       76              76     76      76      76
# M          139      139             139    139     139     139

# %% [markdown]
# # Categorical Data

# %% [markdown]
# ### Ordinal Data

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
le=LabelEncoder()

# %%
data['specialisation']=le.fit_transform(data['specialisation'])
data
# Out:
#             serial_num gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# serial_num
# 0                    1      M  67.00   Others  91.00   Others  Commerce
# 1                    2      M  79.33  Central  78.33   Others   Science
# 2                    3      M  65.00  Central  68.00  Central      Arts
# 3                    4      M  56.00  Central  52.00  Central   Science
# 4                    5      M  85.80  Central  73.60  Central  Commerce
# ...                ...    ...    ...      ...    ...      ...       ...
# 210                211      M  80.60   Others  82.00   Others  Commerce
# 211                212      M  58.00   Others  60.00   Others   Science
# 212                213      M  67.00   Others  67.00   Others  Commerce
# 213                214      F  74.00   Others  66.00   Others  Commerce
# 214                215      M  62.00  Central  58.00   Others   Science
#
#             degree_p   degree_t workex  etest_p  specialisation  mba_p  \
# serial_num
# ...

# %% [markdown]
# ### working on HR & Fin Values

# %%
data.specialisation.map({0:'Fin',1:'HR'},na_action='ignore')
# Out:
# serial_num
# 0       HR
# 1      Fin
# 2      Fin
# 3       HR
# 4      Fin
#       ...
# 210    Fin
# 211    Fin
# 212    Fin
# 213     HR
# 214     HR
# Name: specialisation, Length: 215, dtype: object

# %%
data
# Out:
#             serial_num gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# serial_num
# 0                    1      M  67.00   Others  91.00   Others  Commerce
# 1                    2      M  79.33  Central  78.33   Others   Science
# 2                    3      M  65.00  Central  68.00  Central      Arts
# 3                    4      M  56.00  Central  52.00  Central   Science
# 4                    5      M  85.80  Central  73.60  Central  Commerce
# ...                ...    ...    ...      ...    ...      ...       ...
# 210                211      M  80.60   Others  82.00   Others  Commerce
# 211                212      M  58.00   Others  60.00   Others   Science
# 212                213      M  67.00   Others  67.00   Others  Commerce
# 213                214      F  74.00   Others  66.00   Others  Commerce
# 214                215      M  62.00  Central  58.00   Others   Science
#
#             degree_p   degree_t workex  etest_p  specialisation  mba_p  \
# serial_num
# ...

# %%
data['specialisation']=data['specialisation'] .replace([0,1],['Fin','HR'])

# %%
data
# Out:
#             serial_num gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  \
# serial_num
# 0                    1      M  67.00   Others  91.00   Others  Commerce
# 1                    2      M  79.33  Central  78.33   Others   Science
# 2                    3      M  65.00  Central  68.00  Central      Arts
# 3                    4      M  56.00  Central  52.00  Central   Science
# 4                    5      M  85.80  Central  73.60  Central  Commerce
# ...                ...    ...    ...      ...    ...      ...       ...
# 210                211      M  80.60   Others  82.00   Others  Commerce
# 211                212      M  58.00   Others  60.00   Others   Science
# 212                213      M  67.00   Others  67.00   Others  Commerce
# 213                214      F  74.00   Others  66.00   Others  Commerce
# 214                215      M  62.00  Central  58.00   Others   Science
#
#             degree_p   degree_t workex  etest_p specialisation  mba_p  \
# serial_num
# ...

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data.ssc_p,data.hsc_p,data.degree_p)
plt.show()

# %%
plt.plot(data.ssc_p,data.degree_p,color='blue',linestyle="dashed",marker="o",markerfacecolor="black",markersize=8,linewidth=3)
plt.xlabel('ssc_p',fontsize=20)
plt.ylabel('degree_p',fontsize=20)
plt.show()

# %%
plt.plot(data.hsc_p,data.degree_p)
plt.show()

# %%
plt.plot(data.degree_p)
plt.show()

# %%
data.describe()
# Out:
#        serial_num       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     215.000000
# mean   287032.558140
# std     84313.326308
# min    200000.000000
# 25%    245000.000000
# 50%    268000.000000
# 75%    300000.000000
# max    940000.000000

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000237F06FCBB0>,
# ...
#       dtype=object)

# %%
plt.bar(data.hsc_p,data.degree_p)
# Out:
# <BarContainer object of 215 artists>

# %%
data.plot()
plt.show()

# %%
data.plot(kind='hist')
